# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('markas.csv')
df.head()
# Out:
#                 Markas  Lintang     Bujur
# 0     Markas BaSing Se  25.0330  121.5654
# 1        Markas Omashu  10.3157  123.8854
# 2  Markas Pulau Kyoshi  10.4744   98.9305
# 3       Markas Gaoling  -0.9116  119.9004
# 4        Markas Senlin  23.5565  117.6227

# %%
df2 = pd.read_csv("segment.csv");
df2.head()
# Out:
#      Bujur   Lintang
# 0  -7.2575  112.7521
# 1  -6.2088  106.8456
# 2   6.3500   99.8000
# 3  10.4744   98.9305
# 4  13.7563  100.5018

# %%
plt.figure(figsize=(30, 30));
plt.scatter(data=df, x='Bujur', y='Lintang', c='red');
for i in range(len(df)):
    plt.text(df['Bujur'][i], df['Lintang'][i], df['Markas'][i], ha='center', va='bottom')
plt.plot(df2['Lintang'], df2['Bujur'], c='red');
